# %%
# Load all the libraries
import requests 
import json
import pandas as pd
import numpy as np
import quandl
import matplotlib.pyplot as plt

# %%
# Load the DJIA company symbols from the CSV file
DJIA_Tickers_file = "Resources/DJIA_Ticker_List.csv"
DJIA_Tickers_df = pd.read_csv(DJIA_Tickers_file, encoding="ISO-8859-1")

# %%
# Show just the header
DJIA_Tickers_df.head()
# Out:
#    id symbol                   company exchange                 industry  \
# 0  10    MMM                        3M     NYSE             Conglomerate
# 1  11    AXP  American Express Company     NYSE       Financial services
# 2  12   AAPL                 Apple Inc   NASDAQ   Information Technology
# 3  13     BA                    Boeing     NYSE    Aerospace and defense
# 4  14    CAT           Caterpillar Inc     NYSE  Construction and mining
#
#   quandlcode  weight
# 0    EOD/MMM    5.39
# 1    EOD/AXP    2.80
# 2   EOD/AAPL    5.91
# 3     EOD/BA   10.07
# 4    EOD/CAT    3.49

# %%
DJIA_Tickers_df.loc[0,'quandlcode']
# Out:
# 'EOD/MMM'

# %%
# Need to iteratae thru the 30 of so rows and for each row do a Quandl Get to the respective symbol ...

DJIA_EOD_df = pd.DataFrame()
DJIA2_EOD_df = pd.DataFrame()

# DIA_EOD_df = pd.DataFrame()
# SPY_EOD_df = pd.DataFrame()
# VTI_EOD_df = pd.DataFrame()
# QQQ_EOD_df = pd.DataFrame()
# IWM_EOD_df = pd.DataFrame()

for index, row in DJIA_Tickers_df.iterrows():
    DJIA_EOD_df = quandl.get(row['quandlcode'], authtoken="y7AX1dy3giQQhANZj-7n", start_date="1990-01-01")
    DJIA_EOD_df['symbol'] = row['symbol']
    print(index, row['quandlcode'], row['symbol'])
    DJIA2_EOD_df = DJIA2_EOD_df.append(DJIA_EOD_df)

# Include the following index ETF as follows:
# Dow Jones Industrial Average DIA
# DIA_EOD_df = quandl.get("EOD/DIA", authtoken="y7AX1dy3giQQhANZj-7n", start_date="2018-01-01")
#print("EOD/DIA")
#DIA_EOD_df['symbol'] = "DIA"
# DJIA2_EOD_df = DJIA2_EOD_df.append(DIA_EOD_df)

# S&P 500 Using SPY Index SPY
# SPY_EOD_df = quandl.get("EOD/SPY", authtoken="y7AX1dy3giQQhANZj-7n", start_date="2018-01-01")
# print("EOD/SPY")
# SPY_EOD_df['symbol'] = "SPY"
# DJIA2_EOD_df = DJIA2_EOD_df.append(SPY_EOD_df)

# Nasdaq Composite QQQ
# QQQ_EOD_df = quandl.get("EOD/QQQ", authtoken="y7AX1dy3giQQhANZj-7n", start_date="2018-01-01")
# print("EOD/QQQ")
# QQQ_EOD_df['symbol'] = "QQQ"
# DJIA2_EOD_df = DJIA2_EOD_df.append(QQQ_EOD_df)

# Wilshire 5000 - broadest index of 5000 us stocks VTI
# VTI_EOD_df = quandl.get("EOD/VTI", authtoken="y7AX1dy3giQQhANZj-7n", start_date="2018-01-01")
# print("EOD/VTI")
# VTI_EOD_df['symbol'] = "VTI"
# DJIA2_EOD_df = DJIA2_EOD_df.append(VTI_EOD_df)

# Russel 2000 - second broadest index of 2000 smaller  us stocks IWM
# IWM_EOD_df = quandl.get("EOD/IWM", authtoken="y7AX1dy3giQQhANZj-7n", start_date="2018-01-01")
# print("EOD/IWM")
# IWM_EOD_df['symbol'] = "IWM"
# DJIA2_EOD_df = DJIA2_EOD_df.append(IWM_EOD_df)

# reseting the index to get the date column
DJIA2_EOD_df = DJIA2_EOD_df.reset_index()

# Making sure the date column is of Datetime type
# MMM_df.Date = pd.to_datetime(MMM_df.Date)
DJIA2_EOD_df.rename(columns={'Date': 'daily_date', 'Open': 'daily_open', 'High': 'daily_high', 'Low': 'daily_low', 'Close': 'daily_close', 
                           'Volume': 'daily_volume'}, inplace=True)

if len(DJIA2_EOD_df) > 0:
    df_columns = list(DJIA2_EOD_df)
    df_columns = [x.lower() for x in df_columns]
    columns = ",".join(df_columns)
# Out:
# 0 EOD/MMM MMM
# 1 EOD/AXP AXP
# 2 EOD/AAPL AAPL
# 3 EOD/BA BA
# 4 EOD/CAT CAT
# 5 EOD/CVX CVX
# 6 EOD/CSCO CSCO
# 7 EOD/KO KO
# 8 EOD/DWDP DWDP
# 9 EOD/XOM XOM
# 10 EOD/GS GS
# 11 EOD/HD HD
# 12 EOD/IBM IBM
# 13 EOD/INTC INTC
# 14 EOD/JNJ JNJ
# 15 EOD/JPM JPM
# 16 EOD/MCD MCD
# 17 EOD/MRK MRK
# 18 EOD/MSFT MSFT
# 19 EOD/NKE NKE
# 20 EOD/PFE PFE
# 21 EOD/PG PG
# 22 EOD/TRV TRV
# 23 EOD/UNH UNH
# 24 EOD/UTX UTX
# 25 EOD/VZ VZ
# 26 EOD/V V
# 27 EOD/WMT WMT
# 28 EOD/WBA WBA
# 29 EOD/DIS DIS

# %%
# count of total rows of the dataframe and how the number of columns
DJIA2_EOD_df.shape
# Out:
# (205981, 14)

# %%
# display the column or fields to be inserted
columns
# Out:
# 'daily_date,daily_open,daily_high,daily_low,daily_close,daily_volume,dividend,split,adj_open,adj_high,adj_low,adj_close,adj_volume,symbol'

# %%
# create VALUES('%s', '%s",...) one '%s' per column
values = "VALUES({})".format(",".join(["%s" for _ in df_columns]))

# %%
# display the value strings to the corrosponding fields 
values
# Out:
# 'VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'

# %%
DJIA2_EOD_df.head()
# Out:
#   daily_date  daily_open  daily_high  daily_low  daily_close  daily_volume  \
# 0 1990-01-02       79.38       80.62      79.12        80.50      374000.0
# 1 1990-01-03       80.62       81.88      80.50        81.38      657900.0
# 2 1990-01-04       80.88       83.00      80.88        82.00      634600.0
# 3 1990-01-05       81.62       82.00      80.62        80.62      456400.0
# 4 1990-01-08       80.50       82.88      80.50        82.75      541100.0
#
#    Dividend  Split  Adj_Open  Adj_High   Adj_Low  Adj_Close  Adj_Volume symbol
# 0       0.0    1.0  8.886350  9.025164  8.857244   9.011731   1496000.0    MMM
# 1       0.0    1.0  9.025164  9.166217  9.011731   9.110244   2631600.0    MMM
# 2       0.0    1.0  9.054270  9.291598  9.054270   9.179651   2538400.0    MMM
# 3       0.0    1.0  9.137111  9.179651  9.025164   9.025164   1825600.0    MMM
# 4       0.0    1.0  9.011731  9.278164  9.011731   9.263611   2164400.0    MMM

# %%
# Provide Table Name in the databasae to be loaded
table = 'djia_eod_trading'

# %%
#from sqlalchemy import create_engine
#engine = create_engine('postgresql://postgres:Kolkata1965@localhost:5433/GlobalMarkets')
#MMM_df.to_sql('djia_eod_trading', engine,if_exists='replace')
import psycopg2
import psycopg2.extras
conn = psycopg2.connect(
    host = "localhost",
    database='GlobalMarkets',
    port = 5433,
    user='postgres',
    password='Kolkata1965')
cur = conn.cursor()
#create INSERT INTO table (columns) VALUES('%s',...)
insert_stmt = "INSERT INTO {} ({}) {}".format(table,columns,values)
psycopg2.extras.execute_batch(cur, insert_stmt, DJIA2_EOD_df.values)
# Out:
# /Users/walix008/anaconda3/envs/PythonData/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# Commit and close out the connection
conn.commit()
cur.close()

# %%
## KW - End goal by this evening is to automate this script to read in the 30 or so symbols and load into EOD data
## into the database. 
## Will have more on this evening
##
try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "Kolkata1965",
                                  host = "localhost",
                                  port = 5433,
                                  database = "GlobalMarkets")
    df2 = pd.read_sql('select * from djia_eod_trading', connection)
    df3 = pd.read_sql('select count(*), symbol from djia_eod_trading group by symbol having count(*) > 1', connection)
    #cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")
    # Print PostgreSQL version
    #cursor.execute("select * from djia_desc_tbl;")
    #record = cursor.fetchall()
    #print("You are connected to - ", record,"\n")
except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            #cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# {'user': 'postgres', 'dbname': 'GlobalMarkets', 'host': 'localhost', 'port': '5433', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '1', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# PostgreSQL connection is closed

# %%
df2.head()
# Out:
#    daily_date  daily_open  daily_high  daily_low  daily_close  daily_volume  \
# 0  1990-01-02       79.38       80.62      79.12        80.50        374000
# 1  1990-01-03       80.62       81.88      80.50        81.38        657900
# 2  1990-01-04       80.88       83.00      80.88        82.00        634600
# 3  1990-01-05       81.62       82.00      80.62        80.62        456400
# 4  1990-01-08       80.50       82.88      80.50        82.75        541100
#
#    dividend  split  adj_open  adj_high   adj_low  adj_close  adj_volume symbol
# 0       0.0      1  8.886350  9.025164  8.857244   9.011731     1496000    MMM
# 1       0.0      1  9.025164  9.166217  9.011731   9.110244     2631600    MMM
# 2       0.0      1  9.054270  9.291598  9.054270   9.179651     2538400    MMM
# 3       0.0      1  9.137111  9.179651  9.025164   9.025164     1825600    MMM
# 4       0.0      1  9.011731  9.278164  9.011731   9.263611     2164400    MMM

# %%
df3.head(35)
# Out:
#     count symbol
# 0    7334   AAPL
# 1    7334    AXP
# 2    7334     BA
# 3    7334    CAT
# 4    7276   CSCO
# 5    7334    CVX
# 6    7334    DIS
# 7     361   DWDP
# 8    4975     GS
# 9    7334     HD
# 10   7334    IBM
# 11   7334   INTC
# 12   7334    JNJ
# 13   7334    JPM
# 14   7334     KO
# 15   7334    MCD
# 16   7334    MMM
# 17   7334    MRK
# 18   7334   MSFT
# 19   7334    NKE
# 20   7334    PFE
# 21   7334     PG
# 22   7334    TRV
# 23   7276    UNH
# 24   7334    UTX
# 25   2743      V
# 26   7334     VZ
# 27   7334    WBA
# 28   7334    WMT
# 29   7334    XOM

# %%
# Write out the data collected to a csv file for further processing
djia_eod_trading_file = "Resources/djia_eod_trading.csv"
df2.to_csv(djia_eod_trading_file, encoding='utf-8')
